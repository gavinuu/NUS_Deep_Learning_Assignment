# %%
# splits real clouds & synthetic clouds datasets
# A: synthetic dataset, B: real dataset
# trainA, testA, trainB, testB output to 'cloud/dataset' dir (create the dir first) 

from pathlib import Path
from typing import Tuple, List
import logging
import os

# %%
def browse_folder(
        path: Path,
        A: str,
        B: str) -> Tuple[List[Path], List[Path]]:
    """
    Browse a directory and return a list of all the jpg files in it and its subfolder.
    """
    logging.info(f"Browsing folder {path}")
    filenames_synth, filenames_real = [], []
    for p in path.iterdir():
        if p.is_dir():
            filenames = browse_folder(p, A, B)
            filenames_real.extend(filenames[0])
            filenames_synth.extend(filenames[1])
        elif p.suffix == '.jpg':
            if A in str(p):
                path_synth = p
                path_real = Path(str(p).replace(A, B))
                filenames_synth.append(path_synth)
                filenames_real.append(path_real)
                
    return filenames_synth, filenames_real #to split into train and test datasets

path_main = Path('dataset') #MUST replace with full path if on windows
paths_synth, paths_real = browse_folder(path_main, 'synth', 'real')

# %%
def check_existence(
        filenames: List[Path]) -> None:
    """
    Check if the paths exist.
    Args:
        filenames (List[Path]): List of filenames.
    Returns:
        None
    """
    for file_path in filenames:
        assert file_path.exists(), f'Msissing corresponding real patch of {file_path}'

check_existence(paths_synth)
check_existence(paths_real)

# %%
def create_folders(
        input_dir: Path, 
        folder_list: List[str]) -> None:
    """
    Create folders for training and testing data.
    Args:
        input_dir (Path): Input directory.
        folder_list (List[str]): List of folder names to create.
    Returns:
        None
    """
    os.makedirs(input_dir/folder_list[0], exist_ok=True)
    os.makedirs(input_dir/folder_list[1], exist_ok=True)
    os.makedirs(input_dir/folder_list[2], exist_ok=True)
    os.makedirs(input_dir/folder_list[3], exist_ok=True)

folders_list = ['trainA', 'testA', 'trainB', 'testB']
create_folders(path_main, folders_list)

# %%
def split_train_test(
        filenames: List[Path], 
        alpha: float = 0.9) -> Tuple[List[Path], List[Path]]:
    """
    Split the filenames into training and testing sets.
    Args:
        filenames (List[Path]): List of filenames.
        alpha (float): Ratio of training data to total data.
    Returns:
        Tuple[List[Path], List[Path]]: Training and testing filenames.
    """
    assert 0 < alpha < 1 
    n = len(filenames)
    n_train = int(n * alpha)
    filenames_train = filenames[:n_train]
    filenames_test = filenames[n_train:]
    return filenames_train, filenames_test

paths_trainA, paths_testA = split_train_test(paths_synth) 
paths_trainB, paths_testB = split_train_test(paths_real)

# %%
def create_symlinks(
        filenames: List[Path],
        #input_dir: Path, (excluded)
        split_dir: Path) -> None:
    """
    Create symbolic links for the training and testing images.
    Args:
        filenames (List[Path]): List of filenames.
        input_dir (Path): Input directory.
        split_dir (Path): Split directory.
    Returns:
        None
    """
    for i in range(len(filenames)):
        os.symlink(filenames[i], f'{split_dir}/{i}.jpg')

create_symlinks(paths_trainA, path_main/folders_list[0])
create_symlinks(paths_testA, path_main/folders_list[1])
create_symlinks(paths_trainB, path_main/folders_list[2])
create_symlinks(paths_testB, path_main/folders_list[3])
# Out:
# dataset\patches_real\0.jpg
# dataset\patches_real\1.jpg
# dataset\patches_real\10.jpg
# dataset\patches_real\100.jpg
# dataset\patches_real\1000.jpg
# dataset\patches_real\10000.jpg
# dataset\patches_real\10001.jpg
# dataset\patches_real\10002.jpg
# dataset\patches_real\10003.jpg
# dataset\patches_real\10004.jpg
# dataset\patches_real\10005.jpg
# dataset\patches_real\10006.jpg
# dataset\patches_real\10007.jpg
# dataset\patches_real\10008.jpg
# dataset\patches_real\10009.jpg
# dataset\patches_real\1001.jpg
# dataset\patches_real\10010.jpg
# dataset\patches_real\10011.jpg
# dataset\patches_real\10012.jpg
# dataset\patches_real\10013.jpg
# dataset\patches_real\10014.jpg
# dataset\patches_real\10015.jpg
# dataset\patches_real\10016.jpg
# dataset\patches_real\10017.jpg
# dataset\patches_real\10018.jpg
# dataset\patches_real\10019.jpg
# dataset\patches_real\1002.jpg
# dataset\patches_real\10020.jpg
# dataset\patches_real\10021.jpg
# dataset\patches_real\10022.jpg
# dataset\patches_real\10023.jpg
# dataset\patches_real\10024.jpg
# dataset\patches_real\10025.jpg
# dataset\patches_real\10026.jpg
# dataset\patches_real\10027.jpg
# dataset\patches_real\10028.jpg
# dataset\patches_real\10029.jpg
# dataset\patches_real\1003.jpg
# dataset\patches_real\10030.jpg
# dataset\patches_real\10031.jpg
# dataset\patches_real\10032.jpg
# dataset\patches_real\10033.jpg
# dataset\patches_real\10034.jpg
# dataset\patches_real\10035.jpg
# dataset\patches_real\10036.jpg
# dataset\patches_real\10037.jpg
# dataset\patches_real\10038.jpg
# dataset\patches_real\10039.jpg
# dataset\patches_real\1004.jpg
# dataset\patches_real\10040.jpg
# dataset\patches_real\10041.jpg
# dataset\patches_real\10042.jpg
# dataset\patches_real\10043.jpg
# dataset\patches_real\10044.jpg
# dataset\patches_real\10045.jpg
# dataset\patches_real\10046.jpg
# dataset\patches_real\10047.jpg
# dataset\patches_real\10048.jpg
# dataset\patches_real\10049.jpg
# dataset\patches_real\1005.jpg
# dataset\patches_real\10050.jpg
# dataset\patches_real\10051.jpg
# dataset\patches_real\10052.jpg
# dataset\patches_real\10053.jpg
# dataset\patches_real\10054.jpg
# dataset\patches_real\10055.jpg
# dataset\patches_real\10056.jpg
# dataset\patches_real\10057.jpg
# dataset\patches_real\10058.jpg
# dataset\patches_real\10059.jpg
# dataset\patches_real\1006.jpg
# dataset\patches_real\10060.jpg
# dataset\patches_real\10061.jpg
# dataset\patches_real\10062.jpg
# dataset\patches_real\10063.jpg
# dataset\patches_real\10064.jpg
# dataset\patches_real\10065.jpg
# dataset\patches_real\10066.jpg
# dataset\patches_real\10067.jpg
# dataset\patches_real\10068.jpg
# dataset\patches_real\10069.jpg
# dataset\patches_real\1007.jpg
# dataset\patches_real\10070.jpg
# dataset\patches_real\10071.jpg
# dataset\patches_real\10072.jpg
# dataset\patches_real\10073.jpg
# dataset\patches_real\10074.jpg
# dataset\patches_real\10075.jpg
# dataset\patches_real\10076.jpg
# dataset\patches_real\10077.jpg
# dataset\patches_real\10078.jpg
# dataset\patches_real\10079.jpg
# dataset\patches_real\1008.jpg
# dataset\patches_real\10080.jpg
# dataset\patches_real\10081.jpg
# dataset\patches_real\10082.jpg
# dataset\patches_real\10083.jpg
# dataset\patches_real\10084.jpg
# dataset\patches_real\10085.jpg
# dataset\patches_real\10086.jpg
# dataset\patches_real\10087.jpg
# dataset\patches_real\10088.jpg
# dataset\patches_real\10089.jpg
# dataset\patches_real\1009.jpg
# dataset\patches_real\10090.jpg
# dataset\patches_real\10091.jpg
# dataset\patches_real\10092.jpg
# dataset\patches_real\10093.jpg
# dataset\patches_real\10094.jpg
# dataset\patches_real\10095.jpg
# dataset\patches_real\10096.jpg
# dataset\patches_real\10097.jpg
# dataset\patches_real\10098.jpg
# dataset\patches_real\10099.jpg
# dataset\patches_real\101.jpg
# dataset\patches_real\1010.jpg
# dataset\patches_real\10100.jpg
# dataset\patches_real\10101.jpg
# dataset\patches_real\10102.jpg
# dataset\patches_real\10103.jpg
# dataset\patches_real\10104.jpg
# dataset\patches_real\10105.jpg
# dataset\patches_real\10106.jpg
# dataset\patches_real\10107.jpg
# dataset\patches_real\10108.jpg
# dataset\patches_real\10109.jpg
# dataset\patches_real\1011.jpg
# dataset\patches_real\10110.jpg
# dataset\patches_real\10111.jpg
# dataset\patches_real\10112.jpg
# dataset\patches_real\10113.jpg
# dataset\patches_real\10114.jpg
# dataset\patches_real\10115.jpg
# dataset\patches_real\10116.jpg
# dataset\patches_real\10117.jpg
# dataset\patches_real\10118.jpg
# dataset\patches_real\10119.jpg
# dataset\patches_real\1012.jpg
# dataset\patches_real\10120.jpg
# dataset\patches_real\10121.jpg
# dataset\patches_real\10122.jpg
# dataset\patches_real\10123.jpg
# dataset\patches_real\10124.jpg
# dataset\patches_real\10125.jpg
# dataset\patches_real\10126.jpg
# dataset\patches_real\10127.jpg
# dataset\patches_real\10128.jpg
# dataset\patches_real\10129.jpg
# dataset\patches_real\1013.jpg
# dataset\patches_real\10130.jpg
# dataset\patches_real\10131.jpg
# dataset\patches_real\10132.jpg
# dataset\patches_real\10133.jpg
# dataset\patches_real\10134.jpg
# dataset\patches_real\10135.jpg
# dataset\patches_real\10136.jpg
# dataset\patches_real\10137.jpg
# dataset\patches_real\10138.jpg
# dataset\patches_real\10139.jpg
# dataset\patches_real\1014.jpg
# dataset\patches_real\10140.jpg
# dataset\patches_real\10141.jpg
# dataset\patches_real\10142.jpg
# dataset\patches_real\10143.jpg
# dataset\patches_real\10144.jpg
# dataset\patches_real\10145.jpg
# dataset\patches_real\10146.jpg
# dataset\patches_real\10147.jpg
# dataset\patches_real\10148.jpg
# dataset\patches_real\10149.jpg
# dataset\patches_real\1015.jpg
# dataset\patches_real\10150.jpg
# dataset\patches_real\10151.jpg
# dataset\patches_real\10152.jpg
# dataset\patches_real\10153.jpg
# dataset\patches_real\10154.jpg
# dataset\patches_real\10155.jpg
# dataset\patches_real\10156.jpg
# dataset\patches_real\10157.jpg
# dataset\patches_real\10158.jpg
# dataset\patches_real\10159.jpg
# dataset\patches_real\1016.jpg
# dataset\patches_real\10160.jpg
# dataset\patches_real\10161.jpg
# dataset\patches_real\10162.jpg
# dataset\patches_real\10163.jpg
# dataset\patches_real\10164.jpg
# dataset\patches_real\10165.jpg
# dataset\patches_real\10166.jpg
# dataset\patches_real\10167.jpg
# dataset\patches_real\10168.jpg
# dataset\patches_real\10169.jpg
# dataset\patches_real\1017.jpg
# dataset\patches_real\10170.jpg
# dataset\patches_real\10171.jpg
# dataset\patches_real\10172.jpg
# dataset\patches_real\10173.jpg
# dataset\patches_real\10174.jpg
# dataset\patches_real\10175.jpg
# dataset\patches_real\10176.jpg
# dataset\patches_real\10177.jpg
# dataset\patches_real\10178.jpg
# dataset\patches_real\10179.jpg
# dataset\patches_real\1018.jpg
# dataset\patches_real\10180.jpg
# dataset\patches_real\10181.jpg
# dataset\patches_real\10182.jpg
# dataset\patches_real\10183.jpg
# dataset\patches_real\10184.jpg
# dataset\patches_real\10185.jpg
# dataset\patches_real\10186.jpg
# dataset\patches_real\10187.jpg
# dataset\patches_real\10188.jpg
# dataset\patches_real\10189.jpg
# dataset\patches_real\1019.jpg
# dataset\patches_real\10190.jpg
# dataset\patches_real\10191.jpg
# dataset\patches_real\10192.jpg
# dataset\patches_real\10193.jpg
# dataset\patches_real\10194.jpg
# dataset\patches_real\10195.jpg
# dataset\patches_real\10196.jpg
# dataset\patches_real\10197.jpg
# dataset\patches_real\10198.jpg
# dataset\patches_real\10199.jpg
# dataset\patches_real\102.jpg
# dataset\patches_real\1020.jpg
# dataset\patches_real\10200.jpg
# dataset\patches_real\10201.jpg
# dataset\patches_real\10202.jpg
# dataset\patches_real\10203.jpg
# dataset\patches_real\10204.jpg
# dataset\patches_real\10205.jpg
# dataset\patches_real\10206.jpg
# dataset\patches_real\10207.jpg
# dataset\patches_real\10208.jpg
# dataset\patches_real\10209.jpg
# dataset\patches_real\1021.jpg
# dataset\patches_real\10210.jpg
# dataset\patches_real\10211.jpg
# dataset\patches_real\10212.jpg
# dataset\patches_real\10213.jpg
# dataset\patches_real\10214.jpg
# dataset\patches_real\10215.jpg
# dataset\patches_real\10216.jpg
# dataset\patches_real\10217.jpg
# dataset\patches_real\10218.jpg
# dataset\patches_real\10219.jpg
# dataset\patches_real\1022.jpg
# dataset\patches_real\10220.jpg
# dataset\patches_real\10221.jpg
# dataset\patches_real\10222.jpg
# dataset\patches_real\10223.jpg
# dataset\patches_real\10224.jpg
# dataset\patches_real\10225.jpg
# dataset\patches_real\10226.jpg
# dataset\patches_real\10227.jpg
# dataset\patches_real\10228.jpg
# dataset\patches_real\10229.jpg
# dataset\patches_real\1023.jpg
# dataset\patches_real\10230.jpg
# dataset\patches_real\10231.jpg
# dataset\patches_real\10232.jpg
# dataset\patches_real\10233.jpg
# dataset\patches_real\10234.jpg
# dataset\patches_real\10235.jpg
# dataset\patches_real\10236.jpg
# dataset\patches_real\10237.jpg
# dataset\patches_real\10238.jpg
# dataset\patches_real\10239.jpg
# dataset\patches_real\1024.jpg
# dataset\patches_real\10240.jpg
# dataset\patches_real\10241.jpg
# dataset\patches_real\10242.jpg
# dataset\patches_real\10243.jpg
# dataset\patches_real\10244.jpg
# dataset\patches_real\10245.jpg
# dataset\patches_real\10246.jpg
# dataset\patches_real\10247.jpg
# dataset\patches_real\10248.jpg
# dataset\patches_real\10249.jpg
# dataset\patches_real\1025.jpg
# dataset\patches_real\10250.jpg
# dataset\patches_real\10251.jpg
# dataset\patches_real\10252.jpg
# dataset\patches_real\10253.jpg
# dataset\patches_real\10254.jpg
# dataset\patches_real\10255.jpg
# dataset\patches_real\10256.jpg
# dataset\patches_real\10257.jpg
# dataset\patches_real\10258.jpg
# dataset\patches_real\10259.jpg
# dataset\patches_real\1026.jpg
# dataset\patches_real\10260.jpg
# dataset\patches_real\10261.jpg
# dataset\patches_real\10262.jpg
# dataset\patches_real\10263.jpg
# dataset\patches_real\10264.jpg
# dataset\patches_real\10265.jpg
# dataset\patches_real\10266.jpg
# dataset\patches_real\10267.jpg
# dataset\patches_real\10268.jpg
# dataset\patches_real\10269.jpg
# dataset\patches_real\1027.jpg
# dataset\patches_real\10270.jpg
# dataset\patches_real\10271.jpg
# dataset\patches_real\10272.jpg
# dataset\patches_real\10273.jpg
# dataset\patches_real\10274.jpg
# dataset\patches_real\10275.jpg
# dataset\patches_real\10276.jpg
# dataset\patches_real\10277.jpg
# dataset\patches_real\10278.jpg
# dataset\patches_real\10279.jpg
# dataset\patches_real\1028.jpg
# dataset\patches_real\10280.jpg
# dataset\patches_real\10281.jpg
# dataset\patches_real\10282.jpg
# dataset\patches_real\10283.jpg
# dataset\patches_real\10284.jpg
# dataset\patches_real\10285.jpg
# dataset\patches_real\10286.jpg
# dataset\patches_real\10287.jpg
# dataset\patches_real\10288.jpg
# dataset\patches_real\10289.jpg
# dataset\patches_real\1029.jpg
# dataset\patches_real\10290.jpg
# dataset\patches_real\10291.jpg
# dataset\patches_real\10292.jpg
# dataset\patches_real\10293.jpg
# dataset\patches_real\10294.jpg
# dataset\patches_real\10295.jpg
# dataset\patches_real\10296.jpg
# dataset\patches_real\10297.jpg
# dataset\patches_real\10298.jpg
# dataset\patches_real\10299.jpg
# dataset\patches_real\103.jpg
# dataset\patches_real\1030.jpg
# dataset\patches_real\10300.jpg
# dataset\patches_real\10301.jpg
# dataset\patches_real\10302.jpg
# dataset\patches_real\10303.jpg
# dataset\patches_real\10304.jpg
# dataset\patches_real\10305.jpg
# dataset\patches_real\10306.jpg
# dataset\patches_real\10307.jpg
# dataset\patches_real\10308.jpg
# dataset\patches_real\10309.jpg
# dataset\patches_real\1031.jpg
# dataset\patches_real\10310.jpg
# dataset\patches_real\10311.jpg
# dataset\patches_real\10312.jpg
# dataset\patches_real\10313.jpg
# dataset\patches_real\10314.jpg
# dataset\patches_real\10315.jpg
# dataset\patches_real\10316.jpg
# dataset\patches_real\10317.jpg
# dataset\patches_real\10318.jpg
# dataset\patches_real\10319.jpg
# dataset\patches_real\1032.jpg
# dataset\patches_real\10320.jpg
# dataset\patches_real\10321.jpg
# dataset\patches_real\10322.jpg
# dataset\patches_real\10323.jpg
# dataset\patches_real\10324.jpg
# dataset\patches_real\10325.jpg
# dataset\patches_real\10326.jpg
# dataset\patches_real\10327.jpg
# dataset\patches_real\10328.jpg
# dataset\patches_real\10329.jpg
# dataset\patches_real\1033.jpg
# dataset\patches_real\10330.jpg
# dataset\patches_real\10331.jpg
# dataset\patches_real\10332.jpg
# dataset\patches_real\10333.jpg
# dataset\patches_real\10334.jpg
# dataset\patches_real\10335.jpg
# dataset\patches_real\10336.jpg
# dataset\patches_real\10337.jpg
# dataset\patches_real\10338.jpg
# dataset\patches_real\10339.jpg
# dataset\patches_real\1034.jpg
# dataset\patches_real\10340.jpg
# dataset\patches_real\10341.jpg
# dataset\patches_real\10342.jpg
# dataset\patches_real\10343.jpg
# dataset\patches_real\10344.jpg
# dataset\patches_real\10345.jpg
# dataset\patches_real\10346.jpg
# dataset\patches_real\10347.jpg
# dataset\patches_real\10348.jpg
# dataset\patches_real\10349.jpg
# dataset\patches_real\1035.jpg
# dataset\patches_real\10350.jpg
# dataset\patches_real\10351.jpg
# dataset\patches_real\10352.jpg
# dataset\patches_real\10353.jpg
# dataset\patches_real\10354.jpg
# dataset\patches_real\10355.jpg
# dataset\patches_real\10356.jpg
# dataset\patches_real\10357.jpg
# dataset\patches_real\10358.jpg
# dataset\patches_real\10359.jpg
# dataset\patches_real\1036.jpg
# dataset\patches_real\10360.jpg
# dataset\patches_real\10361.jpg
# dataset\patches_real\10362.jpg
# dataset\patches_real\10363.jpg
# dataset\patches_real\10364.jpg
# dataset\patches_real\10365.jpg
# dataset\patches_real\10366.jpg
# dataset\patches_real\10367.jpg
# dataset\patches_real\10368.jpg
# dataset\patches_real\10369.jpg
# dataset\patches_real\1037.jpg
# dataset\patches_real\10370.jpg
# dataset\patches_real\10371.jpg
# dataset\patches_real\10372.jpg
# dataset\patches_real\10373.jpg
# dataset\patches_real\10374.jpg
# dataset\patches_real\10375.jpg
# dataset\patches_real\10376.jpg
# dataset\patches_real\10377.jpg
# dataset\patches_real\10378.jpg
# dataset\patches_real\10379.jpg
# dataset\patches_real\1038.jpg
# dataset\patches_real\10380.jpg
# dataset\patches_real\10381.jpg
# dataset\patches_real\10382.jpg
# dataset\patches_real\10383.jpg
# dataset\patches_real\10384.jpg
# dataset\patches_real\10385.jpg
# dataset\patches_real\10386.jpg
# dataset\patches_real\10387.jpg
# dataset\patches_real\10388.jpg
# dataset\patches_real\10389.jpg
# dataset\patches_real\1039.jpg
# dataset\patches_real\10390.jpg
# dataset\patches_real\10391.jpg
# dataset\patches_real\10392.jpg
# dataset\patches_real\10393.jpg
# dataset\patches_real\10394.jpg
# dataset\patches_real\10395.jpg
# dataset\patches_real\10396.jpg
# dataset\patches_real\10397.jpg
# dataset\patches_real\10398.jpg
# dataset\patches_real\10399.jpg
# dataset\patches_real\104.jpg
# dataset\patches_real\1040.jpg
# dataset\patches_real\10400.jpg
# dataset\patches_real\10401.jpg
# dataset\patches_real\10402.jpg
# dataset\patches_real\10403.jpg
# dataset\patches_real\10404.jpg
# dataset\patches_real\10405.jpg
# dataset\patches_real\10406.jpg
# dataset\patches_real\10407.jpg
# dataset\patches_real\10408.jpg
# dataset\patches_real\10409.jpg
# dataset\patches_real\1041.jpg
# dataset\patches_real\10410.jpg
# dataset\patches_real\10411.jpg
# dataset\patches_real\10412.jpg
# dataset\patches_real\10413.jpg
# dataset\patches_real\10414.jpg
# dataset\patches_real\10415.jpg
# dataset\patches_real\10416.jpg
# dataset\patches_real\10417.jpg
# dataset\patches_real\10418.jpg
# dataset\patches_real\10419.jpg
# dataset\patches_real\1042.jpg
# dataset\patches_real\10420.jpg
# dataset\patches_real\10421.jpg
# dataset\patches_real\10422.jpg
# dataset\patches_real\10423.jpg
# dataset\patches_real\10424.jpg
# dataset\patches_real\10425.jpg
# dataset\patches_real\10426.jpg
# dataset\patches_real\10427.jpg
# dataset\patches_real\10428.jpg
# dataset\patches_real\10429.jpg
# dataset\patches_real\1043.jpg
# dataset\patches_real\10430.jpg
# dataset\patches_real\10431.jpg
# dataset\patches_real\10432.jpg
# dataset\patches_real\10433.jpg
# dataset\patches_real\10434.jpg
# dataset\patches_real\10435.jpg
# dataset\patches_real\10436.jpg
# dataset\patches_real\10437.jpg
# dataset\patches_real\10438.jpg
# dataset\patches_real\10439.jpg
# dataset\patches_real\1044.jpg
# dataset\patches_real\10440.jpg
# dataset\patches_real\10441.jpg
# dataset\patches_real\10442.jpg
# dataset\patches_real\10443.jpg
# dataset\patches_real\10444.jpg
# dataset\patches_real\10445.jpg
# dataset\patches_real\10446.jpg
# dataset\patches_real\10447.jpg
# dataset\patches_real\10448.jpg
# dataset\patches_real\10449.jpg
# dataset\patches_real\1045.jpg
# dataset\patches_real\10450.jpg
# dataset\patches_real\10451.jpg
# dataset\patches_real\10452.jpg
# dataset\patches_real\10453.jpg
# dataset\patches_real\10454.jpg
# dataset\patches_real\10455.jpg
# dataset\patches_real\10456.jpg
# dataset\patches_real\10457.jpg
# dataset\patches_real\10458.jpg
# dataset\patches_real\10459.jpg
# dataset\patches_real\1046.jpg
# dataset\patches_real\10460.jpg
# dataset\patches_real\10461.jpg
# dataset\patches_real\10462.jpg
# dataset\patches_real\10463.jpg
# dataset\patches_real\10464.jpg
# dataset\patches_real\10465.jpg
# dataset\patches_real\10466.jpg
# dataset\patches_real\10467.jpg
# dataset\patches_real\10468.jpg
# dataset\patches_real\10469.jpg
# dataset\patches_real\1047.jpg
# dataset\patches_real\10470.jpg
# dataset\patches_real\10471.jpg
# dataset\patches_real\10472.jpg
# dataset\patches_real\10473.jpg
# dataset\patches_real\10474.jpg
# dataset\patches_real\10475.jpg
# dataset\patches_real\10476.jpg
# dataset\patches_real\10477.jpg
# dataset\patches_real\10478.jpg
# dataset\patches_real\10479.jpg
# dataset\patches_real\1048.jpg
# dataset\patches_real\10480.jpg
# dataset\patches_real\10481.jpg
# dataset\patches_real\10482.jpg
# dataset\patches_real\10483.jpg
# dataset\patches_real\10484.jpg
# dataset\patches_real\10485.jpg
# dataset\patches_real\10486.jpg
# dataset\patches_real\10487.jpg
# dataset\patches_real\10488.jpg
# dataset\patches_real\10489.jpg
# dataset\patches_real\1049.jpg
# dataset\patches_real\10490.jpg
# dataset\patches_real\10491.jpg
# dataset\patches_real\10492.jpg
# dataset\patches_real\10493.jpg
# dataset\patches_real\10494.jpg
# dataset\patches_real\10495.jpg
# dataset\patches_real\10496.jpg
# dataset\patches_real\10497.jpg
# dataset\patches_real\10498.jpg
# dataset\patches_real\10499.jpg
# dataset\patches_real\105.jpg
# dataset\patches_real\1050.jpg
# dataset\patches_real\10500.jpg
# dataset\patches_real\10501.jpg
# dataset\patches_real\10502.jpg
# dataset\patches_real\10503.jpg
# dataset\patches_real\10504.jpg
# dataset\patches_real\10505.jpg
# dataset\patches_real\10506.jpg
# dataset\patches_real\10507.jpg
# dataset\patches_real\10508.jpg
# dataset\patches_real\10509.jpg
# dataset\patches_real\1051.jpg
# dataset\patches_real\10510.jpg
# dataset\patches_real\10511.jpg
# dataset\patches_real\10512.jpg
# dataset\patches_real\10513.jpg
# dataset\patches_real\10514.jpg
# dataset\patches_real\10515.jpg
# dataset\patches_real\10516.jpg
# dataset\patches_real\10517.jpg
# dataset\patches_real\10518.jpg
# dataset\patches_real\10519.jpg
# dataset\patches_real\1052.jpg
# dataset\patches_real\10520.jpg
# dataset\patches_real\10521.jpg
# dataset\patches_real\10522.jpg
# dataset\patches_real\10523.jpg
# dataset\patches_real\10524.jpg
# dataset\patches_real\10525.jpg
# dataset\patches_real\10526.jpg
# dataset\patches_real\10527.jpg
# dataset\patches_real\10528.jpg
# dataset\patches_real\10529.jpg
# dataset\patches_real\1053.jpg
# dataset\patches_real\10530.jpg
# dataset\patches_real\10531.jpg
# dataset\patches_real\10532.jpg
# dataset\patches_real\10533.jpg
# dataset\patches_real\10534.jpg
# dataset\patches_real\10535.jpg
# dataset\patches_real\10536.jpg
# dataset\patches_real\10537.jpg
# dataset\patches_real\10538.jpg
# dataset\patches_real\10539.jpg
# dataset\patches_real\1054.jpg
# dataset\patches_real\10540.jpg
# dataset\patches_real\10541.jpg
# dataset\patches_real\10542.jpg
# dataset\patches_real\10543.jpg
# dataset\patches_real\10544.jpg
# dataset\patches_real\10545.jpg
# dataset\patches_real\10546.jpg
# dataset\patches_real\10547.jpg
# dataset\patches_real\10548.jpg
# dataset\patches_real\10549.jpg
# dataset\patches_real\1055.jpg
# dataset\patches_real\10550.jpg
# dataset\patches_real\10551.jpg
# dataset\patches_real\10552.jpg
# dataset\patches_real\10553.jpg
# dataset\patches_real\10554.jpg
# dataset\patches_real\10555.jpg
# dataset\patches_real\10556.jpg
# dataset\patches_real\10557.jpg
# dataset\patches_real\10558.jpg
# dataset\patches_real\10559.jpg
# dataset\patches_real\1056.jpg
# dataset\patches_real\10560.jpg
# dataset\patches_real\10561.jpg
# dataset\patches_real\10562.jpg
# dataset\patches_real\10563.jpg
# dataset\patches_real\10564.jpg
# dataset\patches_real\10565.jpg
# dataset\patches_real\10566.jpg
# dataset\patches_real\10567.jpg
# dataset\patches_real\10568.jpg
# dataset\patches_real\10569.jpg
# dataset\patches_real\1057.jpg
# dataset\patches_real\10570.jpg
# dataset\patches_real\10571.jpg
# dataset\patches_real\10572.jpg
# dataset\patches_real\10573.jpg
# dataset\patches_real\10574.jpg
# dataset\patches_real\10575.jpg
# dataset\patches_real\10576.jpg
# dataset\patches_real\10577.jpg
# dataset\patches_real\10578.jpg
# dataset\patches_real\10579.jpg
# dataset\patches_real\1058.jpg
# dataset\patches_real\10580.jpg
# dataset\patches_real\10581.jpg
# dataset\patches_real\10582.jpg
# dataset\patches_real\10583.jpg
# dataset\patches_real\10584.jpg
# dataset\patches_real\10585.jpg
# dataset\patches_real\10586.jpg
# dataset\patches_real\10587.jpg
# dataset\patches_real\10588.jpg
# dataset\patches_real\10589.jpg
# dataset\patches_real\1059.jpg
# dataset\patches_real\10590.jpg
# dataset\patches_real\10591.jpg
# dataset\patches_real\10592.jpg
# dataset\patches_real\10593.jpg
# dataset\patches_real\10594.jpg
# dataset\patches_real\10595.jpg
# dataset\patches_real\10596.jpg
# dataset\patches_real\10597.jpg
# dataset\patches_real\10598.jpg
# dataset\patches_real\10599.jpg
# dataset\patches_real\106.jpg
# dataset\patches_real\1060.jpg
# dataset\patches_real\10600.jpg
# dataset\patches_real\10601.jpg
# dataset\patches_real\10602.jpg
# dataset\patches_real\10603.jpg
# dataset\patches_real\10604.jpg
# dataset\patches_real\10605.jpg
# dataset\patches_real\10606.jpg
# dataset\patches_real\10607.jpg
# dataset\patches_real\10608.jpg
# dataset\patches_real\10609.jpg
# dataset\patches_real\1061.jpg
# dataset\patches_real\10610.jpg
# dataset\patches_real\10611.jpg
# dataset\patches_real\10612.jpg
# dataset\patches_real\10613.jpg
# dataset\patches_real\10614.jpg
# dataset\patches_real\10615.jpg
# dataset\patches_real\10616.jpg
# dataset\patches_real\10617.jpg
# dataset\patches_real\10618.jpg
# dataset\patches_real\10619.jpg
# dataset\patches_real\1062.jpg
# dataset\patches_real\10620.jpg
# dataset\patches_real\10621.jpg
# dataset\patches_real\10622.jpg
# dataset\patches_real\10623.jpg
# dataset\patches_real\10624.jpg
# dataset\patches_real\10625.jpg
# dataset\patches_real\10626.jpg
# dataset\patches_real\10627.jpg
# dataset\patches_real\10628.jpg
# dataset\patches_real\10629.jpg
# dataset\patches_real\1063.jpg
# dataset\patches_real\10630.jpg
# dataset\patches_real\10631.jpg
# dataset\patches_real\10632.jpg
# dataset\patches_real\10633.jpg
# dataset\patches_real\10634.jpg
# dataset\patches_real\10635.jpg
# dataset\patches_real\10636.jpg
# dataset\patches_real\10637.jpg
# dataset\patches_real\10638.jpg
# dataset\patches_real\10639.jpg
# dataset\patches_real\1064.jpg
# dataset\patches_real\10640.jpg
# dataset\patches_real\10641.jpg
# dataset\patches_real\10642.jpg
# dataset\patches_real\10643.jpg
# dataset\patches_real\10644.jpg
# dataset\patches_real\10645.jpg
# dataset\patches_real\10646.jpg
# dataset\patches_real\10647.jpg
# dataset\patches_real\10648.jpg
# dataset\patches_real\10649.jpg
# dataset\patches_real\1065.jpg
# dataset\patches_real\10650.jpg
# dataset\patches_real\10651.jpg
# dataset\patches_real\10652.jpg
# dataset\patches_real\10653.jpg
# dataset\patches_real\10654.jpg
# dataset\patches_real\10655.jpg
# dataset\patches_real\10656.jpg
# dataset\patches_real\10657.jpg
# dataset\patches_real\10658.jpg
# dataset\patches_real\10659.jpg
# dataset\patches_real\1066.jpg
# dataset\patches_real\10660.jpg
# dataset\patches_real\10661.jpg
# dataset\patches_real\10662.jpg
# dataset\patches_real\10663.jpg
# dataset\patches_real\10664.jpg
# dataset\patches_real\10665.jpg
# dataset\patches_real\10666.jpg
# dataset\patches_real\10667.jpg
# dataset\patches_real\10668.jpg
# dataset\patches_real\10669.jpg
# dataset\patches_real\1067.jpg
# dataset\patches_real\10670.jpg
# dataset\patches_real\10671.jpg
# dataset\patches_real\10672.jpg
# dataset\patches_real\10673.jpg
# dataset\patches_real\10674.jpg
# dataset\patches_real\10675.jpg
# dataset\patches_real\10676.jpg
# dataset\patches_real\10677.jpg
# dataset\patches_real\10678.jpg
# dataset\patches_real\10679.jpg
# dataset\patches_real\1068.jpg
# dataset\patches_real\10680.jpg
# dataset\patches_real\10681.jpg
# dataset\patches_real\10682.jpg
# dataset\patches_real\10683.jpg
# dataset\patches_real\10684.jpg
# dataset\patches_real\10685.jpg
# dataset\patches_real\10686.jpg
# dataset\patches_real\10687.jpg
# dataset\patches_real\10688.jpg
# dataset\patches_real\10689.jpg
# dataset\patches_real\1069.jpg
# dataset\patches_real\10690.jpg
# dataset\patches_real\10691.jpg
# dataset\patches_real\10692.jpg
# dataset\patches_real\10693.jpg
# dataset\patches_real\10694.jpg
# dataset\patches_real\10695.jpg
# dataset\patches_real\10696.jpg
# dataset\patches_real\10697.jpg
# dataset\patches_real\10698.jpg
# dataset\patches_real\10699.jpg
# dataset\patches_real\107.jpg
# dataset\patches_real\1070.jpg
# dataset\patches_real\10700.jpg
# dataset\patches_real\10701.jpg
# dataset\patches_real\10702.jpg
# dataset\patches_real\10703.jpg
# dataset\patches_real\10704.jpg
# dataset\patches_real\10705.jpg
# dataset\patches_real\10706.jpg
# dataset\patches_real\10707.jpg
# dataset\patches_real\10708.jpg
# dataset\patches_real\10709.jpg
# dataset\patches_real\1071.jpg
# dataset\patches_real\10710.jpg
# dataset\patches_real\10711.jpg
# dataset\patches_real\10712.jpg
# dataset\patches_real\10713.jpg
# dataset\patches_real\10714.jpg
# dataset\patches_real\10715.jpg
# dataset\patches_real\10716.jpg
# dataset\patches_real\10717.jpg
# dataset\patches_real\10718.jpg
# dataset\patches_real\10719.jpg
# dataset\patches_real\1072.jpg
# dataset\patches_real\10720.jpg
# dataset\patches_real\10721.jpg
# dataset\patches_real\10722.jpg
# dataset\patches_real\10723.jpg
# dataset\patches_real\10724.jpg
# dataset\patches_real\10725.jpg
# dataset\patches_real\10726.jpg
# dataset\patches_real\10727.jpg
# dataset\patches_real\10728.jpg
# dataset\patches_real\10729.jpg
# dataset\patches_real\1073.jpg
# dataset\patches_real\10730.jpg
# dataset\patches_real\10731.jpg
# dataset\patches_real\10732.jpg
# dataset\patches_real\10733.jpg
# dataset\patches_real\10734.jpg
# dataset\patches_real\10735.jpg
# dataset\patches_real\10736.jpg
# dataset\patches_real\10737.jpg
# dataset\patches_real\10738.jpg
# dataset\patches_real\10739.jpg
# dataset\patches_real\1074.jpg
# dataset\patches_real\10740.jpg
# dataset\patches_real\10741.jpg
# dataset\patches_real\10742.jpg
# dataset\patches_real\10743.jpg
# dataset\patches_real\10744.jpg
# dataset\patches_real\10745.jpg
# dataset\patches_real\10746.jpg
# dataset\patches_real\10747.jpg
# dataset\patches_real\10748.jpg
# dataset\patches_real\10749.jpg
# dataset\patches_real\1075.jpg
# dataset\patches_real\10750.jpg
# dataset\patches_real\10751.jpg
# dataset\patches_real\10752.jpg
# dataset\patches_real\10753.jpg
# dataset\patches_real\10754.jpg
# dataset\patches_real\10755.jpg
# dataset\patches_real\10756.jpg
# dataset\patches_real\10757.jpg
# dataset\patches_real\10758.jpg
# dataset\patches_real\10759.jpg
# dataset\patches_real\1076.jpg
# dataset\patches_real\10760.jpg
# dataset\patches_real\10761.jpg
# dataset\patches_real\10762.jpg
# dataset\patches_real\10763.jpg
# dataset\patches_real\10764.jpg
# dataset\patches_real\10765.jpg
# dataset\patches_real\10766.jpg
# dataset\patches_real\10767.jpg
# dataset\patches_real\10768.jpg
# dataset\patches_real\10769.jpg
# dataset\patches_real\1077.jpg
# dataset\patches_real\10770.jpg
# dataset\patches_real\10771.jpg
# dataset\patches_real\10772.jpg
# dataset\patches_real\10773.jpg
# dataset\patches_real\10774.jpg
# dataset\patches_real\10775.jpg
# dataset\patches_real\10776.jpg
# dataset\patches_real\10777.jpg
# dataset\patches_real\10778.jpg
# dataset\patches_real\10779.jpg
# dataset\patches_real\1078.jpg
# dataset\patches_real\10780.jpg
# dataset\patches_real\10781.jpg
# dataset\patches_real\10782.jpg
# dataset\patches_real\10783.jpg
# dataset\patches_real\10784.jpg
# dataset\patches_real\10785.jpg
# dataset\patches_real\10786.jpg
# dataset\patches_real\10787.jpg
# dataset\patches_real\10788.jpg
# dataset\patches_real\10789.jpg
# dataset\patches_real\1079.jpg
# dataset\patches_real\10790.jpg
# dataset\patches_real\10791.jpg
# dataset\patches_real\10792.jpg
# dataset\patches_real\10793.jpg
# dataset\patches_real\10794.jpg
# dataset\patches_real\10795.jpg
# dataset\patches_real\10796.jpg
# dataset\patches_real\10797.jpg
# dataset\patches_real\10798.jpg
# dataset\patches_real\10799.jpg
# dataset\patches_real\108.jpg
# dataset\patches_real\1080.jpg
# dataset\patches_real\10800.jpg
# dataset\patches_real\10801.jpg
# dataset\patches_real\10802.jpg
# dataset\patches_real\10803.jpg
# dataset\patches_real\10804.jpg
# dataset\patches_real\10805.jpg
# dataset\patches_real\10806.jpg
# dataset\patches_real\10807.jpg
# dataset\patches_real\10808.jpg
# dataset\patches_real\10809.jpg
# dataset\patches_real\1081.jpg
# dataset\patches_real\10810.jpg
# dataset\patches_real\10811.jpg
# dataset\patches_real\10812.jpg
# dataset\patches_real\10813.jpg
# dataset\patches_real\10814.jpg
# dataset\patches_real\10815.jpg
# dataset\patches_real\10816.jpg
# dataset\patches_real\10817.jpg
# dataset\patches_real\10818.jpg
# dataset\patches_real\10819.jpg
# dataset\patches_real\1082.jpg
# dataset\patches_real\10820.jpg
# dataset\patches_real\10821.jpg
# dataset\patches_real\10822.jpg
# dataset\patches_real\10823.jpg
# dataset\patches_real\10824.jpg
# dataset\patches_real\10825.jpg
# dataset\patches_real\10826.jpg
# dataset\patches_real\10827.jpg
# dataset\patches_real\10828.jpg
# dataset\patches_real\10829.jpg
# dataset\patches_real\1083.jpg
# dataset\patches_real\10830.jpg
# dataset\patches_real\10831.jpg
# dataset\patches_real\10832.jpg
# dataset\patches_real\10833.jpg
# dataset\patches_real\10834.jpg
# dataset\patches_real\10835.jpg
# dataset\patches_real\10836.jpg
# dataset\patches_real\10837.jpg
# dataset\patches_real\10838.jpg
# dataset\patches_real\10839.jpg
# dataset\patches_real\1084.jpg
# dataset\patches_real\10840.jpg
# dataset\patches_real\10841.jpg
# dataset\patches_real\10842.jpg
# dataset\patches_real\10843.jpg
# dataset\patches_real\10844.jpg
# dataset\patches_real\10845.jpg
# dataset\patches_real\10846.jpg
# dataset\patches_real\10847.jpg
# dataset\patches_real\10848.jpg
# dataset\patches_real\10849.jpg
# dataset\patches_real\1085.jpg
# dataset\patches_real\10850.jpg
# dataset\patches_real\10851.jpg
# dataset\patches_real\10852.jpg
# dataset\patches_real\10853.jpg
# dataset\patches_real\10854.jpg
# dataset\patches_real\10855.jpg
# dataset\patches_real\10856.jpg
# dataset\patches_real\10857.jpg
# dataset\patches_real\10858.jpg
# dataset\patches_real\10859.jpg
# dataset\patches_real\1086.jpg
# dataset\patches_real\10860.jpg
# dataset\patches_real\10861.jpg
# dataset\patches_real\10862.jpg
# dataset\patches_real\10863.jpg
# dataset\patches_real\10864.jpg
# dataset\patches_real\10865.jpg
# dataset\patches_real\10866.jpg
# dataset\patches_real\10867.jpg
# dataset\patches_real\10868.jpg
# dataset\patches_real\10869.jpg
# dataset\patches_real\1087.jpg
# dataset\patches_real\10870.jpg
# dataset\patches_real\10871.jpg
# dataset\patches_real\10872.jpg
# dataset\patches_real\10873.jpg
# dataset\patches_real\10874.jpg
# dataset\patches_real\10875.jpg
# dataset\patches_real\10876.jpg
# dataset\patches_real\10877.jpg
# dataset\patches_real\10878.jpg
# dataset\patches_real\10879.jpg
# dataset\patches_real\1088.jpg
# dataset\patches_real\10880.jpg
# dataset\patches_real\10881.jpg
# dataset\patches_real\10882.jpg
# dataset\patches_real\10883.jpg
# dataset\patches_real\10884.jpg
# dataset\patches_real\10885.jpg
# dataset\patches_real\10886.jpg
# dataset\patches_real\10887.jpg
# dataset\patches_real\10888.jpg
# dataset\patches_real\10889.jpg
# dataset\patches_real\1089.jpg
# dataset\patches_real\10890.jpg
# dataset\patches_real\10891.jpg
# dataset\patches_real\10892.jpg
# dataset\patches_real\10893.jpg
# dataset\patches_real\10894.jpg
# dataset\patches_real\10895.jpg
# dataset\patches_real\10896.jpg
# dataset\patches_real\10897.jpg
# dataset\patches_real\10898.jpg
# dataset\patches_real\10899.jpg
# dataset\patches_real\109.jpg
# dataset\patches_real\1090.jpg
# dataset\patches_real\10900.jpg
# dataset\patches_real\10901.jpg
# dataset\patches_real\10902.jpg
# dataset\patches_real\10903.jpg
# dataset\patches_real\10904.jpg
# dataset\patches_real\10905.jpg
# dataset\patches_real\10906.jpg
# dataset\patches_real\10907.jpg
# dataset\patches_real\10908.jpg
# dataset\patches_real\10909.jpg
# dataset\patches_real\1091.jpg
# dataset\patches_real\10910.jpg
# dataset\patches_real\10911.jpg
# dataset\patches_real\10912.jpg
# dataset\patches_real\10913.jpg
# dataset\patches_real\10914.jpg
# dataset\patches_real\10915.jpg
# dataset\patches_real\10916.jpg
# dataset\patches_real\10917.jpg
# dataset\patches_real\10918.jpg
# dataset\patches_real\10919.jpg
# dataset\patches_real\1092.jpg
# dataset\patches_real\10920.jpg
# dataset\patches_real\10921.jpg
# dataset\patches_real\10922.jpg
# dataset\patches_real\10923.jpg
# dataset\patches_real\10924.jpg
# dataset\patches_real\10925.jpg
# dataset\patches_real\10926.jpg
# dataset\patches_real\10927.jpg
# dataset\patches_real\10928.jpg
# dataset\patches_real\10929.jpg
# dataset\patches_real\1093.jpg
# dataset\patches_real\10930.jpg
# dataset\patches_real\10931.jpg
# dataset\patches_real\10932.jpg
# dataset\patches_real\10933.jpg
# dataset\patches_real\10934.jpg
# dataset\patches_real\10935.jpg
# dataset\patches_real\10936.jpg
# dataset\patches_real\10937.jpg
# dataset\patches_real\10938.jpg
# dataset\patches_real\10939.jpg
# dataset\patches_real\1094.jpg
# dataset\patches_real\10940.jpg
# dataset\patches_real\10941.jpg
# dataset\patches_real\10942.jpg
# dataset\patches_real\10943.jpg
# dataset\patches_real\10944.jpg
# dataset\patches_real\10945.jpg
# dataset\patches_real\10946.jpg
# dataset\patches_real\10947.jpg
# dataset\patches_real\10948.jpg
# dataset\patches_real\10949.jpg
# dataset\patches_real\1095.jpg
# dataset\patches_real\10950.jpg
# dataset\patches_real\10951.jpg
# dataset\patches_real\10952.jpg
# dataset\patches_real\10953.jpg
# dataset\patches_real\10954.jpg
# dataset\patches_real\10955.jpg
# dataset\patches_real\10956.jpg
# dataset\patches_real\10957.jpg
# dataset\patches_real\10958.jpg
# dataset\patches_real\10959.jpg
# dataset\patches_real\1096.jpg
# dataset\patches_real\10960.jpg
# dataset\patches_real\10961.jpg
# dataset\patches_real\10962.jpg
# dataset\patches_real\10963.jpg
# dataset\patches_real\10964.jpg
# dataset\patches_real\10965.jpg
# dataset\patches_real\10966.jpg
# dataset\patches_real\10967.jpg
# dataset\patches_real\10968.jpg
# dataset\patches_real\10969.jpg
# dataset\patches_real\1097.jpg
# dataset\patches_real\10970.jpg
# dataset\patches_real\10971.jpg
# dataset\patches_real\10972.jpg
# dataset\patches_real\10973.jpg
# dataset\patches_real\10974.jpg
# dataset\patches_real\10975.jpg
# dataset\patches_real\10976.jpg
# dataset\patches_real\10977.jpg
# dataset\patches_real\10978.jpg
# dataset\patches_real\10979.jpg
# dataset\patches_real\1098.jpg
# dataset\patches_real\10980.jpg
# dataset\patches_real\10981.jpg
# dataset\patches_real\10982.jpg
# dataset\patches_real\10983.jpg
# dataset\patches_real\10984.jpg
# dataset\patches_real\10985.jpg
# dataset\patches_real\10986.jpg
# dataset\patches_real\10987.jpg
# dataset\patches_real\10988.jpg
# dataset\patches_real\10989.jpg
# dataset\patches_real\1099.jpg
# dataset\patches_real\10990.jpg
# dataset\patches_real\10991.jpg
# dataset\patches_real\10992.jpg
# dataset\patches_real\10993.jpg
# dataset\patches_real\10994.jpg
# dataset\patches_real\10995.jpg
# dataset\patches_real\10996.jpg
# dataset\patches_real\10997.jpg
# dataset\patches_real\10998.jpg
# dataset\patches_real\10999.jpg
# dataset\patches_real\11.jpg
# dataset\patches_real\110.jpg
# dataset\patches_real\1100.jpg
# dataset\patches_real\11000.jpg
# dataset\patches_real\11001.jpg
# dataset\patches_real\11002.jpg
# dataset\patches_real\11003.jpg
# dataset\patches_real\11004.jpg
# dataset\patches_real\11005.jpg
# dataset\patches_real\11006.jpg
# dataset\patches_real\11007.jpg
# dataset\patches_real\11008.jpg
# dataset\patches_real\11009.jpg
# dataset\patches_real\1101.jpg
# dataset\patches_real\11010.jpg
# dataset\patches_real\11011.jpg
# dataset\patches_real\11012.jpg
# dataset\patches_real\11013.jpg
# dataset\patches_real\11014.jpg
# dataset\patches_real\11015.jpg
# dataset\patches_real\11016.jpg
# dataset\patches_real\11017.jpg
# dataset\patches_real\11018.jpg
# dataset\patches_real\11019.jpg
# dataset\patches_real\1102.jpg
# dataset\patches_real\11020.jpg
# dataset\patches_real\11021.jpg
# dataset\patches_real\11022.jpg
# dataset\patches_real\11023.jpg
# dataset\patches_real\11024.jpg
# dataset\patches_real\11025.jpg
# dataset\patches_real\11026.jpg
# dataset\patches_real\11027.jpg
# dataset\patches_real\11028.jpg
# dataset\patches_real\11029.jpg
# dataset\patches_real\1103.jpg
# dataset\patches_real\11030.jpg
# dataset\patches_real\11031.jpg
# dataset\patches_real\11032.jpg
# dataset\patches_real\11033.jpg
# dataset\patches_real\11034.jpg
# dataset\patches_real\11035.jpg
# dataset\patches_real\11036.jpg
# dataset\patches_real\11037.jpg
# dataset\patches_real\11038.jpg
# dataset\patches_real\11039.jpg
# dataset\patches_real\1104.jpg
# dataset\patches_real\11040.jpg
# dataset\patches_real\11041.jpg
# dataset\patches_real\11042.jpg
# dataset\patches_real\11043.jpg
# dataset\patches_real\11044.jpg
# dataset\patches_real\11045.jpg
# dataset\patches_real\11046.jpg
# dataset\patches_real\11047.jpg
# dataset\patches_real\11048.jpg
# dataset\patches_real\11049.jpg
# dataset\patches_real\1105.jpg
# dataset\patches_real\11050.jpg
# dataset\patches_real\11051.jpg
# dataset\patches_real\11052.jpg
# dataset\patches_real\11053.jpg
# dataset\patches_real\11054.jpg
# dataset\patches_real\11055.jpg
# dataset\patches_real\11056.jpg
# dataset\patches_real\11057.jpg
# dataset\patches_real\11058.jpg
# dataset\patches_real\11059.jpg
# dataset\patches_real\1106.jpg
# dataset\patches_real\11060.jpg
# dataset\patches_real\11061.jpg
# dataset\patches_real\11062.jpg
# dataset\patches_real\11063.jpg
# dataset\patches_real\11064.jpg
# dataset\patches_real\11065.jpg
# dataset\patches_real\11066.jpg
# dataset\patches_real\11067.jpg
# dataset\patches_real\11068.jpg
# dataset\patches_real\11069.jpg
# dataset\patches_real\1107.jpg
# dataset\patches_real\11070.jpg
# dataset\patches_real\11071.jpg
# dataset\patches_real\11072.jpg
# dataset\patches_real\11073.jpg
# dataset\patches_real\11074.jpg
# dataset\patches_real\11075.jpg
# dataset\patches_real\11076.jpg
# dataset\patches_real\11077.jpg
# dataset\patches_real\11078.jpg
# dataset\patches_real\11079.jpg
# dataset\patches_real\1108.jpg
# dataset\patches_real\11080.jpg
# dataset\patches_real\11081.jpg
# dataset\patches_real\11082.jpg
# dataset\patches_real\11083.jpg
# dataset\patches_real\11084.jpg
# dataset\patches_real\11085.jpg
# dataset\patches_real\11086.jpg
# dataset\patches_real\11087.jpg
# dataset\patches_real\11088.jpg
# dataset\patches_real\11089.jpg
# dataset\patches_real\1109.jpg
# dataset\patches_real\11090.jpg
# dataset\patches_real\11091.jpg
# dataset\patches_real\11092.jpg
# dataset\patches_real\11093.jpg
# dataset\patches_real\11094.jpg
# dataset\patches_real\11095.jpg
# dataset\patches_real\11096.jpg
# dataset\patches_real\11097.jpg
# dataset\patches_real\11098.jpg
# dataset\patches_real\11099.jpg
# dataset\patches_real\111.jpg
# dataset\patches_real\1110.jpg
# dataset\patches_real\11100.jpg
# dataset\patches_real\11101.jpg
# dataset\patches_real\11102.jpg
# dataset\patches_real\11103.jpg
# dataset\patches_real\11104.jpg
# dataset\patches_real\11105.jpg
# dataset\patches_real\11106.jpg
# dataset\patches_real\11107.jpg
# dataset\patches_real\11108.jpg
# dataset\patches_real\11109.jpg
# dataset\patches_real\1111.jpg
# dataset\patches_real\11110.jpg
# dataset\patches_real\11111.jpg
# dataset\patches_real\11112.jpg
# dataset\patches_real\11113.jpg
# dataset\patches_real\11114.jpg
# dataset\patches_real\11115.jpg
# dataset\patches_real\11116.jpg
# dataset\patches_real\11117.jpg
# dataset\patches_real\11118.jpg
# dataset\patches_real\11119.jpg
# dataset\patches_real\1112.jpg
# dataset\patches_real\11120.jpg
# dataset\patches_real\11121.jpg
# dataset\patches_real\11122.jpg
# dataset\patches_real\11123.jpg
# dataset\patches_real\11124.jpg
# dataset\patches_real\11125.jpg
# dataset\patches_real\11126.jpg
# dataset\patches_real\11127.jpg
# dataset\patches_real\11128.jpg
# dataset\patches_real\11129.jpg
# dataset\patches_real\1113.jpg
# dataset\patches_real\11130.jpg
# dataset\patches_real\11131.jpg
# dataset\patches_real\11132.jpg
# dataset\patches_real\11133.jpg
# dataset\patches_real\11134.jpg
# dataset\patches_real\11135.jpg
# dataset\patches_real\11136.jpg
# dataset\patches_real\11137.jpg
# dataset\patches_real\11138.jpg
# dataset\patches_real\11139.jpg
# dataset\patches_real\1114.jpg
# dataset\patches_real\11140.jpg
# dataset\patches_real\11141.jpg
# dataset\patches_real\11142.jpg
# dataset\patches_real\11143.jpg
# dataset\patches_real\11144.jpg
# dataset\patches_real\11145.jpg
# dataset\patches_real\11146.jpg
# dataset\patches_real\11147.jpg
# dataset\patches_real\11148.jpg
# dataset\patches_real\11149.jpg
# dataset\patches_real\1115.jpg
# dataset\patches_real\11150.jpg
# dataset\patches_real\11151.jpg
# dataset\patches_real\11152.jpg
# dataset\patches_real\11153.jpg
# dataset\patches_real\11154.jpg
# dataset\patches_real\11155.jpg
# dataset\patches_real\11156.jpg
# dataset\patches_real\11157.jpg
# dataset\patches_real\11158.jpg
# dataset\patches_real\11159.jpg
# dataset\patches_real\1116.jpg
# dataset\patches_real\11160.jpg
# dataset\patches_real\11161.jpg
# dataset\patches_real\11162.jpg
# dataset\patches_real\11163.jpg
# dataset\patches_real\11164.jpg
# dataset\patches_real\11165.jpg
# dataset\patches_real\11166.jpg
# dataset\patches_real\11167.jpg
# dataset\patches_real\11168.jpg
# dataset\patches_real\11169.jpg
# dataset\patches_real\1117.jpg
# dataset\patches_real\11170.jpg
# dataset\patches_real\11171.jpg
# dataset\patches_real\11172.jpg
# dataset\patches_real\11173.jpg
# dataset\patches_real\11174.jpg
# dataset\patches_real\11175.jpg
# dataset\patches_real\11176.jpg
# dataset\patches_real\11177.jpg
# dataset\patches_real\11178.jpg
# dataset\patches_real\11179.jpg
# dataset\patches_real\1118.jpg
# dataset\patches_real\11180.jpg
# dataset\patches_real\11181.jpg
# dataset\patches_real\11182.jpg
# dataset\patches_real\11183.jpg
# dataset\patches_real\11184.jpg
# dataset\patches_real\11185.jpg
# dataset\patches_real\11186.jpg
# dataset\patches_real\11187.jpg
# dataset\patches_real\11188.jpg
# dataset\patches_real\11189.jpg
# dataset\patches_real\1119.jpg
# dataset\patches_real\11190.jpg
# dataset\patches_real\11191.jpg
# dataset\patches_real\11192.jpg
# dataset\patches_real\11193.jpg
# dataset\patches_real\11194.jpg
# dataset\patches_real\11195.jpg
# dataset\patches_real\11196.jpg
# dataset\patches_real\11197.jpg
# dataset\patches_real\11198.jpg
# dataset\patches_real\11199.jpg
# dataset\patches_real\112.jpg
# dataset\patches_real\1120.jpg
# dataset\patches_real\11200.jpg
# dataset\patches_real\11201.jpg
# dataset\patches_real\11202.jpg
# dataset\patches_real\11203.jpg
# dataset\patches_real\11204.jpg
# dataset\patches_real\11205.jpg
# dataset\patches_real\11206.jpg
# dataset\patches_real\11207.jpg
# dataset\patches_real\11208.jpg
# dataset\patches_real\11209.jpg
# dataset\patches_real\1121.jpg
# dataset\patches_real\11210.jpg
# dataset\patches_real\11211.jpg
# dataset\patches_real\11212.jpg
# dataset\patches_real\11213.jpg
# dataset\patches_real\11214.jpg
# dataset\patches_real\11215.jpg
# dataset\patches_real\11216.jpg
# dataset\patches_real\11217.jpg
# dataset\patches_real\11218.jpg
# dataset\patches_real\11219.jpg
# dataset\patches_real\1122.jpg
# dataset\patches_real\11220.jpg
# dataset\patches_real\11221.jpg
# dataset\patches_real\11222.jpg
# dataset\patches_real\11223.jpg
# dataset\patches_real\11224.jpg
# dataset\patches_real\11225.jpg
# dataset\patches_real\11226.jpg
# dataset\patches_real\11227.jpg
# dataset\patches_real\11228.jpg
# dataset\patches_real\11229.jpg
# dataset\patches_real\1123.jpg
# dataset\patches_real\11230.jpg
# dataset\patches_real\11231.jpg
# dataset\patches_real\11232.jpg
# dataset\patches_real\11233.jpg
# dataset\patches_real\11234.jpg
# dataset\patches_real\11235.jpg
# dataset\patches_real\11236.jpg
# dataset\patches_real\11237.jpg
# dataset\patches_real\11238.jpg
# dataset\patches_real\11239.jpg
# dataset\patches_real\1124.jpg
# dataset\patches_real\11240.jpg
# dataset\patches_real\11241.jpg
# dataset\patches_real\11242.jpg
# dataset\patches_real\11243.jpg
# dataset\patches_real\11244.jpg
# dataset\patches_real\11245.jpg
# dataset\patches_real\11246.jpg
# dataset\patches_real\11247.jpg
# dataset\patches_real\11248.jpg
# dataset\patches_real\11249.jpg
# dataset\patches_real\1125.jpg
# dataset\patches_real\11250.jpg
# dataset\patches_real\11251.jpg
# dataset\patches_real\11252.jpg
# dataset\patches_real\11253.jpg
# dataset\patches_real\11254.jpg
# dataset\patches_real\11255.jpg
# dataset\patches_real\11256.jpg
# dataset\patches_real\11257.jpg
# dataset\patches_real\11258.jpg
# dataset\patches_real\11259.jpg
# dataset\patches_real\1126.jpg
# dataset\patches_real\11260.jpg
# dataset\patches_real\11261.jpg
# dataset\patches_real\11262.jpg
# dataset\patches_real\11263.jpg
# dataset\patches_real\11264.jpg
# dataset\patches_real\11265.jpg
# dataset\patches_real\11266.jpg
# dataset\patches_real\11267.jpg
# dataset\patches_real\11268.jpg
# dataset\patches_real\11269.jpg
# dataset\patches_real\1127.jpg
# dataset\patches_real\11270.jpg
# dataset\patches_real\11271.jpg
# dataset\patches_real\11272.jpg
# dataset\patches_real\11273.jpg
# dataset\patches_real\11274.jpg
# dataset\patches_real\11275.jpg
# dataset\patches_real\11276.jpg
# dataset\patches_real\11277.jpg
# dataset\patches_real\11278.jpg
# dataset\patches_real\11279.jpg
# dataset\patches_real\1128.jpg
# dataset\patches_real\11280.jpg
# dataset\patches_real\11281.jpg
# dataset\patches_real\11282.jpg
# dataset\patches_real\11283.jpg
# dataset\patches_real\11284.jpg
# dataset\patches_real\11285.jpg
# dataset\patches_real\11286.jpg
# dataset\patches_real\11287.jpg
# dataset\patches_real\11288.jpg
# dataset\patches_real\11289.jpg
# dataset\patches_real\1129.jpg
# dataset\patches_real\11290.jpg
# dataset\patches_real\11291.jpg
# dataset\patches_real\11292.jpg
# dataset\patches_real\11293.jpg
# dataset\patches_real\11294.jpg
# dataset\patches_real\11295.jpg
# dataset\patches_real\11296.jpg
# dataset\patches_real\11297.jpg
# dataset\patches_real\11298.jpg
# dataset\patches_real\11299.jpg
# dataset\patches_real\113.jpg
# dataset\patches_real\1130.jpg
# dataset\patches_real\11300.jpg
# dataset\patches_real\11301.jpg
# dataset\patches_real\11302.jpg
# dataset\patches_real\11303.jpg
# dataset\patches_real\11304.jpg
# dataset\patches_real\11305.jpg
# dataset\patches_real\11306.jpg
# dataset\patches_real\11307.jpg
# dataset\patches_real\11308.jpg
# dataset\patches_real\11309.jpg
# dataset\patches_real\1131.jpg
# dataset\patches_real\11310.jpg
# dataset\patches_real\11311.jpg
# dataset\patches_real\11312.jpg
# dataset\patches_real\11313.jpg
# dataset\patches_real\11314.jpg
# dataset\patches_real\11315.jpg
# dataset\patches_real\11316.jpg
# dataset\patches_real\11317.jpg
# dataset\patches_real\11318.jpg
# dataset\patches_real\11319.jpg
# dataset\patches_real\1132.jpg
# dataset\patches_real\11320.jpg
# dataset\patches_real\11321.jpg
# dataset\patches_real\11322.jpg
# dataset\patches_real\11323.jpg
# dataset\patches_real\11324.jpg
# dataset\patches_real\11325.jpg
# dataset\patches_real\11326.jpg
# dataset\patches_real\11327.jpg
# dataset\patches_real\11328.jpg
# dataset\patches_real\11329.jpg
# dataset\patches_real\1133.jpg
# dataset\patches_real\11330.jpg
# dataset\patches_real\11331.jpg
# dataset\patches_real\11332.jpg
# dataset\patches_real\11333.jpg
# dataset\patches_real\11334.jpg
# dataset\patches_real\11335.jpg
# dataset\patches_real\11336.jpg
# dataset\patches_real\11337.jpg
# dataset\patches_real\11338.jpg
# dataset\patches_real\11339.jpg
# dataset\patches_real\1134.jpg
# dataset\patches_real\11340.jpg
# dataset\patches_real\11341.jpg
# dataset\patches_real\11342.jpg
# dataset\patches_real\11343.jpg
# dataset\patches_real\11344.jpg
# dataset\patches_real\11345.jpg
# dataset\patches_real\11346.jpg
# dataset\patches_real\11347.jpg
# dataset\patches_real\11348.jpg
# dataset\patches_real\11349.jpg
# dataset\patches_real\1135.jpg
# dataset\patches_real\11350.jpg
# dataset\patches_real\11351.jpg
# dataset\patches_real\11352.jpg
# dataset\patches_real\11353.jpg
# dataset\patches_real\11354.jpg
# dataset\patches_real\11355.jpg
# dataset\patches_real\11356.jpg
# dataset\patches_real\11357.jpg
# dataset\patches_real\11358.jpg
# dataset\patches_real\11359.jpg
# dataset\patches_real\1136.jpg
# dataset\patches_real\11360.jpg
# dataset\patches_real\11361.jpg
# dataset\patches_real\11362.jpg
# dataset\patches_real\11363.jpg
# dataset\patches_real\11364.jpg
# dataset\patches_real\11365.jpg
# dataset\patches_real\11366.jpg
# dataset\patches_real\11367.jpg
# dataset\patches_real\11368.jpg
# dataset\patches_real\11369.jpg
# dataset\patches_real\1137.jpg
# dataset\patches_real\11370.jpg
# dataset\patches_real\11371.jpg
# dataset\patches_real\11372.jpg
# dataset\patches_real\11373.jpg
# dataset\patches_real\11374.jpg
# dataset\patches_real\11375.jpg
# dataset\patches_real\11376.jpg
# dataset\patches_real\11377.jpg
# dataset\patches_real\11378.jpg
# dataset\patches_real\11379.jpg
# dataset\patches_real\1138.jpg
# dataset\patches_real\11380.jpg
# dataset\patches_real\11381.jpg
# dataset\patches_real\11382.jpg
# dataset\patches_real\11383.jpg
# dataset\patches_real\11384.jpg
# dataset\patches_real\11385.jpg
# dataset\patches_real\11386.jpg
# dataset\patches_real\11387.jpg
# dataset\patches_real\11388.jpg
# dataset\patches_real\11389.jpg
# dataset\patches_real\1139.jpg
# dataset\patches_real\11390.jpg
# dataset\patches_real\11391.jpg
# dataset\patches_real\11392.jpg
# dataset\patches_real\11393.jpg
# dataset\patches_real\11394.jpg
# dataset\patches_real\11395.jpg
# ...
# dataset\patches_synth\9533.jpg
# dataset\patches_synth\9534.jpg
# dataset\patches_synth\9535.jpg
# dataset\patches_synth\9536.jpg
# dataset\patches_synth\9537.jpg
# dataset\patches_synth\9538.jpg
# dataset\patches_synth\9539.jpg
# dataset\patches_synth\954.jpg
# dataset\patches_synth\9540.jpg
# dataset\patches_synth\9541.jpg
# dataset\patches_synth\9542.jpg
# dataset\patches_synth\9543.jpg
# dataset\patches_synth\9544.jpg
# dataset\patches_synth\9545.jpg
# dataset\patches_synth\9546.jpg
# dataset\patches_synth\9547.jpg
# dataset\patches_synth\9548.jpg
# dataset\patches_synth\9549.jpg
# dataset\patches_synth\955.jpg
# dataset\patches_synth\9550.jpg
# dataset\patches_synth\9551.jpg
# dataset\patches_synth\9552.jpg
# dataset\patches_synth\9553.jpg
# dataset\patches_synth\9554.jpg
# dataset\patches_synth\9555.jpg
# dataset\patches_synth\9556.jpg
# dataset\patches_synth\9557.jpg
# dataset\patches_synth\9558.jpg
# dataset\patches_synth\9559.jpg
# dataset\patches_synth\956.jpg
# dataset\patches_synth\9560.jpg
# dataset\patches_synth\9561.jpg
# dataset\patches_synth\9562.jpg
# dataset\patches_synth\9563.jpg
# dataset\patches_synth\9564.jpg
# dataset\patches_synth\9565.jpg
# dataset\patches_synth\9566.jpg
# dataset\patches_synth\9567.jpg
# dataset\patches_synth\9568.jpg
# dataset\patches_synth\9569.jpg
# dataset\patches_synth\957.jpg
# dataset\patches_synth\9570.jpg
# dataset\patches_synth\9571.jpg
# dataset\patches_synth\9572.jpg
# dataset\patches_synth\9573.jpg
# dataset\patches_synth\9574.jpg
# dataset\patches_synth\9575.jpg
# dataset\patches_synth\9576.jpg
# dataset\patches_synth\9577.jpg
# dataset\patches_synth\9578.jpg
# dataset\patches_synth\9579.jpg
# dataset\patches_synth\958.jpg
# dataset\patches_synth\9580.jpg
# dataset\patches_synth\9581.jpg
# dataset\patches_synth\9582.jpg
# dataset\patches_synth\9583.jpg
# dataset\patches_synth\9584.jpg
# dataset\patches_synth\9585.jpg
# dataset\patches_synth\9586.jpg
# dataset\patches_synth\9587.jpg
# dataset\patches_synth\9588.jpg
# dataset\patches_synth\9589.jpg
# dataset\patches_synth\959.jpg
# dataset\patches_synth\9590.jpg
# dataset\patches_synth\9591.jpg
# dataset\patches_synth\9592.jpg
# dataset\patches_synth\9593.jpg
# dataset\patches_synth\9594.jpg
# dataset\patches_synth\9595.jpg
# dataset\patches_synth\9596.jpg
# dataset\patches_synth\9597.jpg
# dataset\patches_synth\9598.jpg
# dataset\patches_synth\9599.jpg
# dataset\patches_synth\96.jpg
# dataset\patches_synth\960.jpg
# dataset\patches_synth\9600.jpg
# dataset\patches_synth\9601.jpg
# dataset\patches_synth\9602.jpg
# dataset\patches_synth\9603.jpg
# dataset\patches_synth\9604.jpg
# dataset\patches_synth\9605.jpg
# dataset\patches_synth\9606.jpg
# dataset\patches_synth\9607.jpg
# dataset\patches_synth\9608.jpg
# dataset\patches_synth\9609.jpg
# dataset\patches_synth\961.jpg
# dataset\patches_synth\9610.jpg
# dataset\patches_synth\9611.jpg
# dataset\patches_synth\9612.jpg
# dataset\patches_synth\9613.jpg
# dataset\patches_synth\9614.jpg
# dataset\patches_synth\9615.jpg
# dataset\patches_synth\9616.jpg
# dataset\patches_synth\9617.jpg
# dataset\patches_synth\9618.jpg
# dataset\patches_synth\9619.jpg
# dataset\patches_synth\962.jpg
# dataset\patches_synth\9620.jpg
# dataset\patches_synth\9621.jpg
# dataset\patches_synth\9622.jpg
# dataset\patches_synth\9623.jpg
# dataset\patches_synth\9624.jpg
# dataset\patches_synth\9625.jpg
# dataset\patches_synth\9626.jpg
# dataset\patches_synth\9627.jpg
# dataset\patches_synth\9628.jpg
# dataset\patches_synth\9629.jpg
# dataset\patches_synth\963.jpg
# dataset\patches_synth\9630.jpg
# dataset\patches_synth\9631.jpg
# dataset\patches_synth\9632.jpg
# dataset\patches_synth\9633.jpg
# dataset\patches_synth\9634.jpg
# dataset\patches_synth\9635.jpg
# dataset\patches_synth\9636.jpg
# dataset\patches_synth\9637.jpg
# dataset\patches_synth\9638.jpg
# dataset\patches_synth\9639.jpg
# dataset\patches_synth\964.jpg
# dataset\patches_synth\9640.jpg
# dataset\patches_synth\9641.jpg
# dataset\patches_synth\9642.jpg
# dataset\patches_synth\9643.jpg
# dataset\patches_synth\9644.jpg
# dataset\patches_synth\9645.jpg
# dataset\patches_synth\9646.jpg
# dataset\patches_synth\9647.jpg
# dataset\patches_synth\9648.jpg
# dataset\patches_synth\9649.jpg
# dataset\patches_synth\965.jpg
# dataset\patches_synth\9650.jpg
# dataset\patches_synth\9651.jpg
# dataset\patches_synth\9652.jpg
# dataset\patches_synth\9653.jpg
# dataset\patches_synth\9654.jpg
# dataset\patches_synth\9655.jpg
# dataset\patches_synth\9656.jpg
# dataset\patches_synth\9657.jpg
# dataset\patches_synth\9658.jpg
# dataset\patches_synth\9659.jpg
# dataset\patches_synth\966.jpg
# dataset\patches_synth\9660.jpg
# dataset\patches_synth\9661.jpg
# dataset\patches_synth\9662.jpg
# dataset\patches_synth\9663.jpg
# dataset\patches_synth\9664.jpg
# dataset\patches_synth\9665.jpg
# dataset\patches_synth\9666.jpg
# dataset\patches_synth\9667.jpg
# dataset\patches_synth\9668.jpg
# dataset\patches_synth\9669.jpg
# dataset\patches_synth\967.jpg
# dataset\patches_synth\9670.jpg
# dataset\patches_synth\9671.jpg
# dataset\patches_synth\9672.jpg
# dataset\patches_synth\9673.jpg
# dataset\patches_synth\9674.jpg
# dataset\patches_synth\9675.jpg
# dataset\patches_synth\9676.jpg
# dataset\patches_synth\9677.jpg
# dataset\patches_synth\9678.jpg
# dataset\patches_synth\9679.jpg
# dataset\patches_synth\968.jpg
# dataset\patches_synth\9680.jpg
# dataset\patches_synth\9681.jpg
# dataset\patches_synth\9682.jpg
# dataset\patches_synth\9683.jpg
# dataset\patches_synth\9684.jpg
# dataset\patches_synth\9685.jpg
# dataset\patches_synth\9686.jpg
# dataset\patches_synth\9687.jpg
# dataset\patches_synth\9688.jpg
# dataset\patches_synth\9689.jpg
# dataset\patches_synth\969.jpg
# dataset\patches_synth\9690.jpg
# dataset\patches_synth\9691.jpg
# dataset\patches_synth\9692.jpg
# dataset\patches_synth\9693.jpg
# dataset\patches_synth\9694.jpg
# dataset\patches_synth\9695.jpg
# dataset\patches_synth\9696.jpg
# dataset\patches_synth\9697.jpg
# dataset\patches_synth\9698.jpg
# dataset\patches_synth\9699.jpg
# dataset\patches_synth\97.jpg
# dataset\patches_synth\970.jpg
# dataset\patches_synth\9700.jpg
# dataset\patches_synth\9701.jpg
# dataset\patches_synth\9702.jpg
# dataset\patches_synth\9703.jpg
# dataset\patches_synth\9704.jpg
# dataset\patches_synth\9705.jpg
# dataset\patches_synth\9706.jpg
# dataset\patches_synth\9707.jpg
# dataset\patches_synth\9708.jpg
# dataset\patches_synth\9709.jpg
# dataset\patches_synth\971.jpg
# dataset\patches_synth\9710.jpg
# dataset\patches_synth\9711.jpg
# dataset\patches_synth\9712.jpg
# dataset\patches_synth\9713.jpg
# dataset\patches_synth\9714.jpg
# dataset\patches_synth\9715.jpg
# dataset\patches_synth\9716.jpg
# dataset\patches_synth\9717.jpg
# dataset\patches_synth\9718.jpg
# dataset\patches_synth\9719.jpg
# dataset\patches_synth\972.jpg
# dataset\patches_synth\9720.jpg
# dataset\patches_synth\9721.jpg
# dataset\patches_synth\9722.jpg
# dataset\patches_synth\9723.jpg
# dataset\patches_synth\9724.jpg
# dataset\patches_synth\9725.jpg
# dataset\patches_synth\9726.jpg
# dataset\patches_synth\9727.jpg
# dataset\patches_synth\9728.jpg
# dataset\patches_synth\9729.jpg
# dataset\patches_synth\973.jpg
# dataset\patches_synth\9730.jpg
# dataset\patches_synth\9731.jpg
# dataset\patches_synth\9732.jpg
# dataset\patches_synth\9733.jpg
# dataset\patches_synth\9734.jpg
# dataset\patches_synth\9735.jpg
# dataset\patches_synth\9736.jpg
# dataset\patches_synth\9737.jpg
# dataset\patches_synth\9738.jpg
# dataset\patches_synth\9739.jpg
# dataset\patches_synth\974.jpg
# dataset\patches_synth\9740.jpg
# dataset\patches_synth\9741.jpg
# dataset\patches_synth\9742.jpg
# dataset\patches_synth\9743.jpg
# dataset\patches_synth\9744.jpg
# dataset\patches_synth\9745.jpg
# dataset\patches_synth\9746.jpg
# dataset\patches_synth\9747.jpg
# dataset\patches_synth\9748.jpg
# dataset\patches_synth\9749.jpg
# dataset\patches_synth\975.jpg
# dataset\patches_synth\9750.jpg
# dataset\patches_synth\9751.jpg
# dataset\patches_synth\9752.jpg
# dataset\patches_synth\9753.jpg
# dataset\patches_synth\9754.jpg
# dataset\patches_synth\9755.jpg
# dataset\patches_synth\9756.jpg
# dataset\patches_synth\9757.jpg
# dataset\patches_synth\9758.jpg
# dataset\patches_synth\9759.jpg
# dataset\patches_synth\976.jpg
# dataset\patches_synth\9760.jpg
# dataset\patches_synth\9761.jpg
# dataset\patches_synth\9762.jpg
# dataset\patches_synth\9763.jpg
# dataset\patches_synth\9764.jpg
# dataset\patches_synth\9765.jpg
# dataset\patches_synth\9766.jpg
# dataset\patches_synth\9767.jpg
# dataset\patches_synth\9768.jpg
# dataset\patches_synth\9769.jpg
# dataset\patches_synth\977.jpg
# dataset\patches_synth\9770.jpg
# dataset\patches_synth\9771.jpg
# dataset\patches_synth\9772.jpg
# dataset\patches_synth\9773.jpg
# dataset\patches_synth\9774.jpg
# dataset\patches_synth\9775.jpg
# dataset\patches_synth\9776.jpg
# dataset\patches_synth\9777.jpg
# dataset\patches_synth\9778.jpg
# dataset\patches_synth\9779.jpg
# dataset\patches_synth\978.jpg
# dataset\patches_synth\9780.jpg
# dataset\patches_synth\9781.jpg
# dataset\patches_synth\9782.jpg
# dataset\patches_synth\9783.jpg
# dataset\patches_synth\9784.jpg
# dataset\patches_synth\9785.jpg
# dataset\patches_synth\9786.jpg
# dataset\patches_synth\9787.jpg
# dataset\patches_synth\9788.jpg
# dataset\patches_synth\9789.jpg
# dataset\patches_synth\979.jpg
# dataset\patches_synth\9790.jpg
# dataset\patches_synth\9791.jpg
# dataset\patches_synth\9792.jpg
# dataset\patches_synth\9793.jpg
# dataset\patches_synth\9794.jpg
# dataset\patches_synth\9795.jpg
# dataset\patches_synth\9796.jpg
# dataset\patches_synth\9797.jpg
# dataset\patches_synth\9798.jpg
# dataset\patches_synth\9799.jpg
# dataset\patches_synth\98.jpg
# dataset\patches_synth\980.jpg
# dataset\patches_synth\9800.jpg
# dataset\patches_synth\9801.jpg
# dataset\patches_synth\9802.jpg
# dataset\patches_synth\9803.jpg
# dataset\patches_synth\9804.jpg
# dataset\patches_synth\9805.jpg
# dataset\patches_synth\9806.jpg
# dataset\patches_synth\9807.jpg
# dataset\patches_synth\9808.jpg
# dataset\patches_synth\9809.jpg
# dataset\patches_synth\981.jpg
# dataset\patches_synth\9810.jpg
# dataset\patches_synth\9811.jpg
# dataset\patches_synth\9812.jpg
# dataset\patches_synth\9813.jpg
# dataset\patches_synth\9814.jpg
# dataset\patches_synth\9815.jpg
# dataset\patches_synth\9816.jpg
# dataset\patches_synth\9817.jpg
# dataset\patches_synth\9818.jpg
# dataset\patches_synth\9819.jpg
# dataset\patches_synth\982.jpg
# dataset\patches_synth\9820.jpg
# dataset\patches_synth\9821.jpg
# dataset\patches_synth\9822.jpg
# dataset\patches_synth\9823.jpg
# dataset\patches_synth\9824.jpg
# dataset\patches_synth\9825.jpg
# dataset\patches_synth\9826.jpg
# dataset\patches_synth\9827.jpg
# dataset\patches_synth\9828.jpg
# dataset\patches_synth\9829.jpg
# dataset\patches_synth\983.jpg
# dataset\patches_synth\9830.jpg
# dataset\patches_synth\9831.jpg
# dataset\patches_synth\9832.jpg
# dataset\patches_synth\9833.jpg
# dataset\patches_synth\9834.jpg
# dataset\patches_synth\9835.jpg
# dataset\patches_synth\9836.jpg
# dataset\patches_synth\9837.jpg
# dataset\patches_synth\9838.jpg
# dataset\patches_synth\9839.jpg
# dataset\patches_synth\984.jpg
# dataset\patches_synth\9840.jpg
# dataset\patches_synth\9841.jpg
# dataset\patches_synth\9842.jpg
# dataset\patches_synth\9843.jpg
# dataset\patches_synth\9844.jpg
# dataset\patches_synth\9845.jpg
# dataset\patches_synth\9846.jpg
# dataset\patches_synth\9847.jpg
# dataset\patches_synth\9848.jpg
# dataset\patches_synth\9849.jpg
# dataset\patches_synth\985.jpg
# dataset\patches_synth\9850.jpg
# dataset\patches_synth\9851.jpg
# dataset\patches_synth\9852.jpg
# dataset\patches_synth\9853.jpg
# dataset\patches_synth\9854.jpg
# dataset\patches_synth\9855.jpg
# dataset\patches_synth\9856.jpg
# dataset\patches_synth\9857.jpg
# dataset\patches_synth\9858.jpg
# dataset\patches_synth\9859.jpg
# dataset\patches_synth\986.jpg
# dataset\patches_synth\9860.jpg
# dataset\patches_synth\9861.jpg
# dataset\patches_synth\9862.jpg
# dataset\patches_synth\9863.jpg
# dataset\patches_synth\9864.jpg
# dataset\patches_synth\9865.jpg
# dataset\patches_synth\9866.jpg
# dataset\patches_synth\9867.jpg
# dataset\patches_synth\9868.jpg
# dataset\patches_synth\9869.jpg
# dataset\patches_synth\987.jpg
# dataset\patches_synth\9870.jpg
# dataset\patches_synth\9871.jpg
# dataset\patches_synth\9872.jpg
# dataset\patches_synth\9873.jpg
# dataset\patches_synth\9874.jpg
# dataset\patches_synth\9875.jpg
# dataset\patches_synth\9876.jpg
# dataset\patches_synth\9877.jpg
# dataset\patches_synth\9878.jpg
# dataset\patches_synth\9879.jpg
# dataset\patches_synth\988.jpg
# dataset\patches_synth\9880.jpg
# dataset\patches_synth\9881.jpg
# dataset\patches_synth\9882.jpg
# dataset\patches_synth\9883.jpg
# dataset\patches_synth\9884.jpg
# dataset\patches_synth\9885.jpg
# dataset\patches_synth\9886.jpg
# dataset\patches_synth\9887.jpg
# dataset\patches_synth\9888.jpg
# dataset\patches_synth\9889.jpg
# dataset\patches_synth\989.jpg
# dataset\patches_synth\9890.jpg
# dataset\patches_synth\9891.jpg
# dataset\patches_synth\9892.jpg
# dataset\patches_synth\9893.jpg
# dataset\patches_synth\9894.jpg
# dataset\patches_synth\9895.jpg
# dataset\patches_synth\9896.jpg
# dataset\patches_synth\9897.jpg
# dataset\patches_synth\9898.jpg
# dataset\patches_synth\9899.jpg
# dataset\patches_synth\99.jpg
# dataset\patches_synth\990.jpg
# dataset\patches_synth\9900.jpg
# dataset\patches_synth\9901.jpg
# dataset\patches_synth\9902.jpg
# dataset\patches_synth\9903.jpg
# dataset\patches_synth\9904.jpg
# dataset\patches_synth\9905.jpg
# dataset\patches_synth\9906.jpg
# dataset\patches_synth\9907.jpg
# dataset\patches_synth\9908.jpg
# dataset\patches_synth\9909.jpg
# dataset\patches_synth\991.jpg
# dataset\patches_synth\9910.jpg
# dataset\patches_synth\9911.jpg
# dataset\patches_synth\9912.jpg
# dataset\patches_synth\9913.jpg
# dataset\patches_synth\9914.jpg
# dataset\patches_synth\9915.jpg
# dataset\patches_synth\9916.jpg
# dataset\patches_synth\9917.jpg
# dataset\patches_synth\9918.jpg
# dataset\patches_synth\9919.jpg
# dataset\patches_synth\992.jpg
# dataset\patches_synth\9920.jpg
# dataset\patches_synth\9921.jpg
# dataset\patches_synth\9922.jpg
# dataset\patches_synth\9923.jpg
# dataset\patches_synth\9924.jpg
# dataset\patches_synth\9925.jpg
# dataset\patches_synth\9926.jpg
# dataset\patches_synth\9927.jpg
# dataset\patches_synth\9928.jpg
# dataset\patches_synth\9929.jpg
# dataset\patches_synth\993.jpg
# dataset\patches_synth\9930.jpg
# dataset\patches_synth\9931.jpg
# dataset\patches_synth\9932.jpg
# dataset\patches_synth\9933.jpg
# dataset\patches_synth\9934.jpg
# dataset\patches_synth\9935.jpg
# dataset\patches_synth\9936.jpg
# dataset\patches_synth\9937.jpg
# dataset\patches_synth\9938.jpg
# dataset\patches_synth\9939.jpg
# dataset\patches_synth\994.jpg
# dataset\patches_synth\9940.jpg
# dataset\patches_synth\9941.jpg
# dataset\patches_synth\9942.jpg
# dataset\patches_synth\9943.jpg
# dataset\patches_synth\9944.jpg
# dataset\patches_synth\9945.jpg
# dataset\patches_synth\9946.jpg
# dataset\patches_synth\9947.jpg
# dataset\patches_synth\9948.jpg
# dataset\patches_synth\9949.jpg
# dataset\patches_synth\995.jpg
# dataset\patches_synth\9950.jpg
# dataset\patches_synth\9951.jpg
# dataset\patches_synth\9952.jpg
# dataset\patches_synth\9953.jpg
# dataset\patches_synth\9954.jpg
# dataset\patches_synth\9955.jpg
# dataset\patches_synth\9956.jpg
# dataset\patches_synth\9957.jpg
# dataset\patches_synth\9958.jpg
# dataset\patches_synth\9959.jpg
# dataset\patches_synth\996.jpg
# dataset\patches_synth\9960.jpg
# dataset\patches_synth\9961.jpg
# dataset\patches_synth\9962.jpg
# dataset\patches_synth\9963.jpg
# dataset\patches_synth\9964.jpg
# dataset\patches_synth\9965.jpg
# dataset\patches_synth\9966.jpg
# dataset\patches_synth\9967.jpg
# dataset\patches_synth\9968.jpg
# dataset\patches_synth\9969.jpg
# dataset\patches_synth\997.jpg
# dataset\patches_synth\9970.jpg
# dataset\patches_synth\9971.jpg
# dataset\patches_synth\9972.jpg
# dataset\patches_synth\9973.jpg
# dataset\patches_synth\9974.jpg
# dataset\patches_synth\9975.jpg
# dataset\patches_synth\9976.jpg
# dataset\patches_synth\9977.jpg
# dataset\patches_synth\9978.jpg
# dataset\patches_synth\9979.jpg
# dataset\patches_synth\998.jpg
# dataset\patches_synth\9980.jpg
# dataset\patches_synth\9981.jpg
# dataset\patches_synth\9982.jpg
# dataset\patches_synth\9983.jpg
# dataset\patches_synth\9984.jpg
# dataset\patches_synth\9985.jpg
# dataset\patches_synth\9986.jpg
# dataset\patches_synth\9987.jpg
# dataset\patches_synth\9988.jpg
# dataset\patches_synth\9989.jpg
# dataset\patches_synth\999.jpg
# dataset\patches_synth\9990.jpg
# dataset\patches_synth\9991.jpg
# dataset\patches_synth\9992.jpg
# dataset\patches_synth\9993.jpg
# dataset\patches_synth\9994.jpg
# dataset\patches_synth\9995.jpg
# dataset\patches_synth\9996.jpg
# dataset\patches_synth\9997.jpg
# dataset\patches_synth\9998.jpg
# dataset\patches_synth\9999.jpg
